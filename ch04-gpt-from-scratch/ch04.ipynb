# %% [markdown]
# # 第 4 章：从零搭建 GPT 模型
#
# 拼成完整 GPT-2 124M。核心组件在 src/gpt/model.py。

# %%
import torch
from src.gpt import GPTModel, GPT_CONFIG_124M, generate_text_simple
torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
print("参数量:", f"{sum(p.numel() for p in model.parameters()):,}")
