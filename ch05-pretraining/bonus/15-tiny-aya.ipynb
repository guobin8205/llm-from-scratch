# %% [markdown]
# # ch05 Bonus 15：TinyAya 实现
#
# > 对照官方 `rasbt/LLMs-from-scratch` ch05 对应子目录
# > **参考真实模型**：TinyAya
#
# ## 一句话
#
# 多语言模型 TinyAya 从零实现。Aya 系列专注多语言能力，TinyAya 是其小规模版本。
#
# ## 原理详解
#
# 多语言模型 TinyAya 从零实现。Aya 系列专注多语言能力，TinyAya 是其小规模版本。
#
# ---
# > 📌 本 notebook 聚焦**原理理解**（讲清解决什么问题、怎么改造）。
# > 完整可运行实现见官方仓库对应子目录。

# %%
# 概念示意
print('📚 TinyAya 实现')
print('参考模型: TinyAya')
print('核心: 多语言模型 TinyAya 从零实现。Aya 系列专注多语言能力，TinyAya 是其小规模版本。...')
